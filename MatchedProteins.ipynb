# %%
import DisorderFromAlphaFold as DISORDER
from Bio.PDB import PDBParser
import pandas as pd
import numpy as np
parser = PDBParser()
import os

# %%
AFMatchesTest = pd.read_csv('./TestsAndDemo/test_AF_match_info.csv')

# %%
CONFIG = {'PATH_TO_ROOT_PDB': '',
          'pLDDT_DISORDER_THRESHOLD': 70,
          'pLDDT_ORDER_THRESHOLD': 71,
          'CONSECUTIVE_DISORDER_THRESHOLD': 20,
          'CONSECUTIVE_ORDER_THRESHOLD': 20}

# %%
AFMatchesTest_WithFracs = DISORDER.addOrderFractionToDFofAFMatches_Config(AFMatchesTest, CONFIG, True)
# Out:
# AF-D0PV95-F1-model_v4.pdb - Truncated Match, read from res 1 to res 541
# 	Disordered Frac: 34.4, Order Frac: 56.6
# AF-P35637-F1-model_v4.pdb - Truncated Match, read from res 1 to res 242
# 	Disordered Frac: 100.0, Order Frac: 0.0
# AF-P35637-F1-model_v4.pdb - Truncated Match, read from res 1 to res 40
# 	Disordered Frac: 100.0, Order Frac: 0.0
# AF-P35637-F1-model_v4.pdb - Truncated Match, read from res 1 to res 163
# 	Disordered Frac: 100.0, Order Frac: 0.0
# AF-P35637-F1-model_v4.pdb - Truncated Match, read from res 1 to res 315
# 	Disordered Frac: 89.5, Order Frac: 10.5
# AF-P35637-F1-model_v4.pdb - Truncated Match, read from res 1 to res 214
# 	Disordered Frac: 100.0, Order Frac: 0.0
# AF-P09651-F1-model_v4.pdb - Truncated Match, read from res 1 to res 185
# 	Disordered Frac: 0.0, Order Frac: 95.7
# AF-P09651-F1-model_v4.pdb - Truncated Match, read from res 1 to res 40
# 	Disordered Frac: 0.0, Order Frac: 80.0
# AF-P09651-F1-model_v4.pdb - Truncated Match, read from res 1 to res 186
# 	Disordered Frac: 0.0, Order Frac: 95.7
# AF-P40070-F1-model_v4.pdb - Truncated Match, read from res 1 to res 97
# 	Disordered Frac: 0.0, Order Frac: 87.6
# AF-P32588-F1-model_v4.pdb - Truncated Match, read from res 1 to res 85
# 	Disordered Frac: 70.6, Order Frac: 0.0
# AF-P31483-F1-model_v4.pdb - Truncated Match, read from res 1 to res 97
# 	Disordered Frac: 0.0, Order Frac: 76.3
# AF-P06748-F1-model_v4.pdb - Exact Match,
# 	Disordered Frac: 41.8, Order Frac: 53.7
# AF-P78352-F1-model_v4.pdb - Truncated Match, read from res 1 to res 416
# 	Disordered Frac: 29.3, Order Frac: 66.1
# AF-P78352-F1-model_v4.pdb - Exact Match,
# 	Disordered Frac: 19.9, Order Frac: 72.5
# AF-Q13148-F1-model_v4.pdb - Truncated Match, read from res 1 to res 147
# 	Disordered Frac: 17.0, Order Frac: 65.3
# AF-Q06787-F1-model_v4.pdb - Truncated Match, read from res 1 to res 40
# 	Disordered Frac: 0.0, Order Frac: 95.0
# AF-Q06787-F1-model_v4.pdb - Truncated Match, read from res 1 to res 188
# 	Disordered Frac: 0.0, Order Frac: 96.8
# AF-Q06787-F1-model_v4.pdb - Exact Match,
# 	Disordered Frac: 41.9, Order Frac: 55.9
# AF-Q06787-F1-model_v4.pdb - Truncated Match, read from res 1 to res 455
# 	Disordered Frac: 16.9, Order Frac: 77.6
# AF-P45973-F1-model_v4.pdb - Exact Match,
# 	Disordered Frac: 20.9, Order Frac: 52.4
# AF-Q9UHD9-F1-model_v4.pdb - Truncated Match, read from res 1 to res 138
# 	Disordered Frac: 46.4, Order Frac: 53.6
# AF-Q9UHD9-F1-model_v4.pdb - Truncated Match, read from res 1 to res 576
# 	Disordered Frac: 59.7, Order Frac: 12.8
# AF-O60500-F1-model_v4.pdb - Truncated Match, read from res 1 to res 165
# 	Disordered Frac: 19.4, Order Frac: 75.8
# AF-G5EBV6-F1-model_v4.pdb - Truncated Match, read from res 1 to res 620
# 	Disordered Frac: 27.6, Order Frac: 65.0
# AF-G5EBV6-F1-model_v4.pdb - Truncated Match, read from res 1 to res 215
# 	Disordered Frac: 0.0, Order Frac: 95.3
# AF-G5EBV6-F1-model_v4.pdb - Truncated Match, read from res 1 to res 479
# 	Disordered Frac: 6.3, Order Frac: 84.1
# AF-G5EBV6-F1-model_v4.pdb - Truncated Match, read from res 1 to res 260
# 	Disordered Frac: 0.0, Order Frac: 90.4
# AF-O94752-F1-model_v4.pdb - Truncated Match, read from res 1 to res 194
# 	Disordered Frac: 45.4, Order Frac: 42.3
# AF-Q13501-F1-model_v4.pdb - Exact Match,
# 	Disordered Frac: 41.4, Order Frac: 48.6
# AF-Q01844-F1-model_v4.pdb - Truncated Match, read from res 1 to res 284
# 	Disordered Frac: 100.0, Order Frac: 0.0
# AF-Q01844-F1-model_v4.pdb - Truncated Match, read from res 1 to res 372
# 	Disordered Frac: 96.5, Order Frac: 0.0
# AF-P39517-F1-model_v4.pdb - Exact Match,
# 	Disordered Frac: 20.6, Order Frac: 78.7
# AF-Q9TZQ3-F1-model_v4.pdb - Truncated Match, read from res 1 to res 672
# 	Disordered Frac: 33.2, Order Frac: 59.1
# AF-Q9TZQ3-F1-model_v4.pdb - Truncated Match, read from res 1 to res 215
# 	Disordered Frac: 0.0, Order Frac: 90.2
# AF-Q9TZQ3-F1-model_v4.pdb - Truncated Match, read from res 1 to res 161
# 	Disordered Frac: 0.0, Order Frac: 97.5
# AF-G5EC37-F1-model_v4.pdb - Exact Match,
# 	Disordered Frac: 34.0, Order Frac: 55.1
# AF-Q95XR4-F1-model_v4.pdb - Exact Match,
# 	Disordered Frac: 17.2, Order Frac: 72.0
# AF-A0A2K3DA85-F1-model_v4.pdb - Truncated Match, read from res 1 to res 272
# 	Disordered Frac: 99.6, Order Frac: 0.0
# AF-P00873-F1-model_v4.pdb - Truncated Match, read from res 1 to res 140
# 	Disordered Frac: 31.4, Order Frac: 68.6
# AF-P17600-F1-model_v4.pdb - Truncated Match, read from res 1 to res 308
# 	Disordered Frac: 36.0, Order Frac: 64.0
# AF-P83916-F1-model_v4.pdb - Exact Match,
# 	Disordered Frac: 20.0, Order Frac: 62.7
# AF-P40337-F1-model_v4.pdb - Truncated Match, read from res 1 to res 16
# 	Disordered Frac: 0.0, Order Frac: 0.0
# AF-P05067-F1-model_v4.pdb - Truncated Match, read from res 1 to res 17
# 	Disordered Frac: 0.0, Order Frac: 0.0
# AF-Q9NQI0-F1-model_v4.pdb - Truncated Match, read from res 1 to res 236
# 	Disordered Frac: 100.0, Order Frac: 0.0
# AF-P19622-F1-model_v4.pdb - Exact Match,
# 	Disordered Frac: 65.8, Order Frac: 21.9
# AF-Q01860-F1-model_v4.pdb - Exact Match,
# 	Disordered Frac: 57.5, Order Frac: 37.5
# AF-P04637-F1-model_v4.pdb - Exact Match,
# 	Disordered Frac: 41.2, Order Frac: 57.0
# AF-Q9W4I7-F1-model_v4.pdb - Truncated Match, read from res 1 to res 228
# 	Disordered Frac: 92.1, Order Frac: 0.0
# AF-Q9W4I7-F1-model_v4.pdb - Truncated Match, read from res 1 to res 162
# 	Disordered Frac: 87.7, Order Frac: 0.0
# AF-P16554-F1-model_v4.pdb - Truncated Match, read from res 1 to res 139
# 	Disordered Frac: 30.9, Order Frac: 52.5
# AF-O60563-F1-model_v4.pdb - Truncated Match, read from res 1 to res 193
# 	Disordered Frac: 0.0, Order Frac: 95.3
# AF-Q13627-F1-model_v4.pdb - Truncated Match, read from res 1 to res 196
# 	Disordered Frac: 45.4, Order Frac: 46.4
# AF-P01012-F1-model_v4.pdb - Exact Match,
# 	Disordered Frac: 0.0, Order Frac: 92.5
# AF-O00571-F1-model_v4.pdb - Truncated Match, read from res 1 to res 168
# 	Disordered Frac: 76.2, Order Frac: 0.0
# AF-Q03513-F1-model_v4.pdb - Truncated Match, read from res 1 to res 344
# 	Disordered Frac: 21.5, Order Frac: 73.3
# AF-Q9NSC5-F1-model_v4.pdb - Exact Match,
# 	Disordered Frac: 13.3, Order Frac: 75.6
# AF-P15502-F1-model_v4.pdb - Truncated Match, read from res 1 to res 36
# 	Disordered Frac: 0.0, Order Frac: 0.0
# AF-P10636-F1-model_v4.pdb - Truncated Match, read from res 1 to res 117
# 	Disordered Frac: 100.0, Order Frac: 0.0
# AF-P10636-F1-model_v4.pdb - Truncated Match, read from res 1 to res 126
# 	Disordered Frac: 100.0, Order Frac: 0.0
# AF-P10636-F1-model_v4.pdb - Truncated Match, read from res 1 to res 198
# 	Disordered Frac: 100.0, Order Frac: 0.0
# AF-Q8SWR8-F1-model_v4.pdb - Truncated Match, read from res 1 to res 400
# 	Disordered Frac: 46.0, Order Frac: 32.8

# %%
AFMatchesTest_WithFracs.to_csv('./TestsAndDemo/test_AF_match_info_WithOrderFracs.csv')
